# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
filterwarnings = 'ignore'

# %%
df = pd.read_csv("investments.csv")
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# 2            40,000  operating          EST        NaN        Tallinn
# 3         15,00,000  operating          GBR        NaN         London
# 4            60,000  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0

# %%
df.columns
# Out:
# Index(['name', 'homepage_url', 'category_list', 'market', 'funding_total_usd',
#        'status', 'country_code', 'state_code', 'region', 'city',
#        'funding_rounds', 'founded_year', 'debt_financing', 'grant'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49438 entries, 0 to 49437
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               49437 non-null  object
#  1   homepage_url       45989 non-null  object
#  2   category_list      45477 non-null  object
#  3   market             45470 non-null  object
#  4   funding_total_usd  49438 non-null  object
#  5   status             48124 non-null  object
#  6   country_code       44165 non-null  object
#  7   state_code         30161 non-null  object
#  8   region             44165 non-null  object
#  9   city               43322 non-null  object
#  10  funding_rounds     49438 non-null  int64
#  11  founded_year       38482 non-null  float64
#  12  debt_financing     49438 non-null  int64
#  13  grant              49438 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 5.3+ MB

# %%
df.select_dtypes(np.number)
# Out:
#        funding_rounds  founded_year  debt_financing  grant
# 0                   1        2012.0               0      0
# 1                   2           NaN               0      0
# 2                   1        2012.0               0      0
# 3                   1        2011.0               0      0
# 4                   2        2014.0               0      0
# ...               ...           ...             ...    ...
# 49433               1        2013.0               0      0
# 49434               1           NaN               0      0
# 49435               5        2012.0               0      0
# 49436               1           NaN               0      0
# 49437               4        1999.0        17000000      0
#
# [49438 rows x 4 columns]

# %%
df.select_dtypes(include = "object")
# Out:
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                   Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list               market  \
# 0             |Entertainment|Politics|Social Media|News|                 News
# 1                                                |Games|                Games
# 2                                 |Publishing|Education|           Publishing
# 3      |Electronics|Guides|Coffee|Restaurants|Music|i...          Electronics
# 4                          |Tourism|Entertainment|Games|              Tourism
# ...                                                  ...                  ...
# 49433  |Analytics|Gamification|Developer APIs|iOS|And...            Education
# 49434                              |Enterprise Software|  Enterprise Software
# 49435      |Web Development|Advertising|Wireless|Mobile|      Web Development
# 49436                                            |Games|                Games
# 49437                              |Enterprise Software|  Enterprise Software
#
#       funding_total_usd     status country_code state_code         region  \
# 0             17,50,000   acquired          USA         NY  New York City
# 1             40,00,000  operating          USA         CA    Los Angeles
# 2                40,000  operating          EST        NaN        Tallinn
# 3             15,00,000  operating          GBR        NaN         London
# 4                60,000  operating          USA         TX         Dallas
# ...                 ...        ...          ...        ...            ...
# 49433          3,20,000  operating          GBR        NaN         London
# 49434         15,87,301  operating          CHN        NaN        Beijing
# 49435            97,398  operating          HRV        NaN          Split
# 49436         93,00,000  operating          NaN        NaN            NaN
# 49437       4,50,00,000  operating          USA         NY  New York City
#
#               city
# 0         New York
# 1      Los Angeles
# 2          Tallinn
# 3           London
# 4       Fort Worth
# ...            ...
# 49433       London
# 49434      Beijing
# 49435        Split
# 49436          NaN
# 49437     New York
#
# [49438 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49438 entries, 0 to 49437
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               49437 non-null  object
#  1   homepage_url       45989 non-null  object
#  2   category_list      45477 non-null  object
#  3   market             45470 non-null  object
#  4   funding_total_usd  49438 non-null  object
#  5   status             48124 non-null  object
#  6   country_code       44165 non-null  object
#  7   state_code         30161 non-null  object
#  8   region             44165 non-null  object
#  9   city               43322 non-null  object
#  10  funding_rounds     49438 non-null  int64
#  11  founded_year       38482 non-null  float64
#  12  debt_financing     49438 non-null  int64
#  13  grant              49438 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 5.3+ MB

# %%
df.describe()
# Out:
#        funding_rounds  founded_year  debt_financing         grant
# count    49438.000000  38482.000000    4.943800e+04  4.943800e+04
# mean         1.696205   2007.359129    1.888157e+06  1.628453e+05
# std          1.294213      7.579203    1.382046e+08  5.612088e+06
# min          1.000000   1902.000000    0.000000e+00  0.000000e+00
# 25%          1.000000   2006.000000    0.000000e+00  0.000000e+00
# 50%          1.000000   2010.000000    0.000000e+00  0.000000e+00
# 75%          2.000000   2012.000000    0.000000e+00  0.000000e+00
# max         18.000000   2014.000000    3.007950e+10  7.505000e+08

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# 2            40,000  operating          EST        NaN        Tallinn
# 3         15,00,000  operating          GBR        NaN         London
# 4            60,000  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# name                  0.002023
# homepage_url          6.976415
# category_list         8.012056
# market                8.026215
# funding_total_usd     0.000000
# status                2.657875
# country_code         10.665885
# state_code           38.992273
# region               10.665885
# city                 12.371051
# funding_rounds        0.000000
# founded_year         22.161091
# debt_financing        0.000000
# grant                 0.000000
# dtype: float64

# %%
df.groupby('country_code')['name'].count()
# Out:
# country_code
# ALB        1
# ARE       66
# ARG      149
# ARM        2
# AUS      314
#        ...
# USA    28793
# UZB        1
# VNM       21
# ZAF       52
# ZWE        1
# Name: name, Length: 115, dtype: int64

# %%
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# 2            40,000  operating          EST        NaN        Tallinn
# 3         15,00,000  operating          GBR        NaN         London
# 4            60,000  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0

# %%
df[df.status.isin(['operating','acquired'])].shape[0]/len(df)*100
# Out:
# 92.07694486022898

# %%
df.founded_year.isnull().sum()
# Out:
# 10956

# %%
df["category_list_count"] = df['category_list'].apply(lambda x : len(str(x).split("|"))-2)
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# 2            40,000  operating          EST        NaN        Tallinn
# 3         15,00,000  operating          GBR        NaN         London
# 4            60,000  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    category_list_count
# 0                    4
# 1                    1
# 2                    2
# 3                   10
# 4                    3

# %%
## df['funding_total_usd'] = df.funding_total_usd.apply(lambda x : x.replace(',','').replace('-','0')).astype(float)

# %%
df.groupby('country_code')['funding_total_usd'].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py in array_func(values)
#     339             try:
# --> 340                 result = self.grouper._cython_operation(
#     341                     "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     977         ngroups = self.ngroups
# --> 978         return cy_op.cython_operation(
#     979             values=values,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     638
# --> 639         return self._cython_op_ndim_compat(
#     640             values,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, **kwargs)
#     480             values2d = values[None, :]
# --> 481             res = self._call_cython_op(
#     482                 values2d,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, **kwargs)
#     540         out_shape = self._get_output_shape(ngroups, values)
# --> 541         func, values = self.get_cython_func_and_vals(values, is_numeric)
#     542         out_dtype = self.get_out_dtype(values.dtype)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in get_cython_func_and_vals(self, values, is_numeric)
#     203
# --> 204         func = self._get_cython_function(kind, how, values.dtype, is_numeric)
#     205
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     168                 # raise NotImplementedError here rather than TypeError later
# --> 169                 raise NotImplementedError(
#     170                     f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1601         try:
# -> 1602             x = float(x)
#    1603         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '-'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1605             try:
# -> 1606                 x = complex(x)
#    1607             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3764/3985654899.py in <module>
# ----> 1 df.groupby('country_code')['funding_total_usd'].mean()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1663         numeric_only = self._resolve_numeric_only(numeric_only)
#    1664
# -> 1665         result = self._cython_agg_general(
#    1666             "mean",
#    1667             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     350             return result
#     351
# --> 352         result = array_func(objvals)
#     353
#     354         ser = self.obj._constructor(
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py in array_func(values)
#     346                 # try to python agg
#     347                 # TODO: shouldn't min_count matter?
# --> 348                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#     349
#     350             return result
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1374         #  should always be preserved by the implemented aggregations
#    1375         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1376         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1377
#    1378         if isinstance(values, Categorical):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#    1026
#    1027         else:
# -> 1028             result = self._aggregate_series_fast(obj, func)
#    1029
#    1030         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#    1051         ids = ids.take(indexer)
#    1052         sgrouper = libreduction.SeriesGrouper(obj, func, ids, ngroups)
# -> 1053         result, _ = sgrouper.get_result()
#    1054         return result
#    1055
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1665         result = self._cython_agg_general(
#    1666             "mean",
# -> 1667             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1668             numeric_only=numeric_only,
#    1669         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
#   10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10352                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10353             )
# > 10354         return self._reduce(
#   10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     663
#     664     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 665     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     666
#     667     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1607             except ValueError as err:
#    1608                 # e.g. "foo"
# -> 1609                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1610     return x
#    1611
#
# TypeError: Could not convert - to numeric

# %%
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# 2            40,000  operating          EST        NaN        Tallinn
# 3         15,00,000  operating          GBR        NaN         London
# 4            60,000  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    category_list_count
# 0                    4
# 1                    1
# 2                    2
# 3                   10
# 4                    3

# %%
df.groupby("country_code")['funding_total_usd'].sum()
# Out:
# country_code
# ALB                                                    -
# ARE    3,00,00,0006,00,00,0001,00,0001,50,00016,00,00...
# ARG    49,12,3931,31,5688,50,0003,50,00012,25,00025,0...
# ARM                                  2,65,17,5002,95,476
# AUS    1,00,0002,70,0003,83,0003,00,000-1,05,65130,10...
#                              ...
# USA    17,50,00040,00,00060,00070,00,000---17,50,000-...
# UZB                                               90,000
# VNM    -9,00,00,000----1,00,000-35,00,0001,50,00,0001...
# ZAF    -3,35,00,000-20,0002,50,00,000-28,50,00037,00,...
# ZWE                                          1,00,00,000
# Name: funding_total_usd, Length: 115, dtype: object

# %%
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# 2            40,000  operating          EST        NaN        Tallinn
# 3         15,00,000  operating          GBR        NaN         London
# 4            60,000  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    category_list_count
# 0                    4
# 1                    1
# 2                    2
# 3                   10
# 4                    3

# %%
df.funding_total_usd = df['funding_total_usd'].apply(lambda x : x.replace(',', '').replace('-','0')).astype(float)

# %%
df.groupby(['country_code','region'])['funding_total_usd'].mean()
# Out:
# country_code  region
# ALB           Tirana          0.000000e+00
# ARE           Abu Dhabi       1.562500e+07
#               Dubai           9.651332e+06
# ARG           ARG - Other     3.049519e+05
#               Buenos Aires    1.760614e+06
#                                   ...
# ZAF           Cape Town       1.559547e+07
#               Durban          0.000000e+00
#               Johannesburg    6.091429e+06
#               ZAF - Other     0.000000e+00
# ZWE           Harare          1.000000e+07
# Name: funding_total_usd, Length: 1096, dtype: float64

# %%
df[df.funding_rounds == 1]['name'].shape[0]
# Out:
# 32039

# %%
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# 2            40,000  operating          EST        NaN        Tallinn
# 3         15,00,000  operating          GBR        NaN         London
# 4            60,000  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    category_list_count
# 0                    4
# 1                    1
# 2                    2
# 3                   10
# 4                    3

# %%
df.status.apply(lambda x : 'A' if x == 'acquired' else 'O' if x == 'operating' else 'C' if x == 'closed' else 'Missing' )
# Out:
# 0        A
# 1        O
# 2        O
# 3        O
# 4        O
#         ..
# 49433    O
# 49434    O
# 49435    O
# 49436    O
# 49437    O
# Name: status, Length: 49438, dtype: object

# %%
df[df.debt_financing > 0]['name'].count()
# Out:
# 4225

# %%
import re
df.homepage_url.apply(lambda x : re.sub('http://www.|.com', '', str(x))).head()
# Out:
# 0              waywire
# 1    http://enjoyandtv
# 2    rockyourpaper.org
# 3       InTouchNetwork
# 4                  nan
# Name: homepage_url, dtype: object

# %%
df.tail()
# Out:
#                                 name               homepage_url  \
# 49433                          Zzish       http://www.zzish.com
# 49434  ZZNode Science and Technology      http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.     http://www.zzzzapp.com
# 49436                  [a]list games  http://www.alistgames.com
# 49437                          [x+1]   http://www.xplusone.com/
#
#                                            category_list               market  \
# 49433  |Analytics|Gamification|Developer APIs|iOS|And...            Education
# 49434                              |Enterprise Software|  Enterprise Software
# 49435      |Web Development|Advertising|Wireless|Mobile|      Web Development
# 49436                                            |Games|                Games
# 49437                              |Enterprise Software|  Enterprise Software
#
#       funding_total_usd     status country_code state_code         region  \
# 49433          3,20,000  operating          GBR        NaN         London
# 49434         15,87,301  operating          CHN        NaN        Beijing
# 49435            97,398  operating          HRV        NaN          Split
# 49436         93,00,000  operating          NaN        NaN            NaN
# 49437       4,50,00,000  operating          USA         NY  New York City
#
#              city  funding_rounds  founded_year  debt_financing  grant  \
# 49433      London               1        2013.0               0      0
# 49434     Beijing               1           NaN               0      0
# 49435       Split               5        2012.0               0      0
# 49436  other_city               1           NaN               0      0
# 49437    New York               4        1999.0        17000000      0
#
#        category_list_count
# 49433                    6
# 49434                    1
# 49435                    4
# 49436                    1
# 49437                    1

# %%
import warnings
filterwarnings = 'ignore'
df.cnt_name = df.groupby('market')['name'].count()

##df.head()

# %%
df.city.fillna('other_city', inplace = True)

# %%
## df.groupby('city')['funding_total_usd'].mean()

# %%
df.country_code.fillna("other_country", inplace = True)

# %%
df.funding_total_usd = df['funding_total_usd'].apply(lambda x : x.replace(',', '').replace('-','0')).astype(float)

# %%
df.groupby('country_code')['funding_total_usd'].transform(lambda x: x/np.max(x))
# Out:
# 0        0.000058
# 1        0.000133
# 2        0.002106
# 3        0.002381
# 4        0.000002
#            ...
# 49433    0.000508
# 49434    0.000496
# 49435    0.064932
# 49436    0.008809
# 49437    0.001496
# Name: funding_total_usd, Length: 49438, dtype: float64

# %%
df.groupby('city')['funding_total_usd'].mean()
# Out:
# city
# 6 October City    1.450000e+05
# A Coruña          1.236930e+06
# Aachen            6.448845e+06
# Aalborg           1.166667e+05
# Aarhus            2.546595e+06
#                       ...
# Évora             0.000000e+00
# Évry              2.212513e+05
# Ísafjörður        4.000000e+06
# Örnsköldsvik      0.000000e+00
# Østerby Havn      8.550000e+05
# Name: funding_total_usd, Length: 4189, dtype: float64

# %%
fig, ax = plt.subplots(1,2,figsize = (20,5))
ax[0].hist(df.funding_total_usd)
ax[0].set_xlabel('funding_total_usd')
ax[0].set_ylabel('count of funding_total_usd')
ax[0].set_title('histogram of funding_total_usd')

ax[1].hist(np.log1p(df.funding_total_usd))
ax[1].set_xlabel('log of funding_total_usd')
ax[1].set_ylabel('count of funding_total_usd')
ax[1].set_title('histogram of log transformed funding_total_usd')
plt.show()

# %%
df.groupby('market')['funding_total_usd'].max()
# Out:
# market
# 3D                20600000.0
# 3D Printing       22300000.0
# 3D Technology      9140352.0
# Accounting       181625355.0
# Ad Targeting      89000000.0
#                     ...
# iOS               95000000.0
# iPad              14078664.0
# iPhone            30250000.0
# iPod Touch         2638000.0
# mHealth            3300000.0
# Name: funding_total_usd, Length: 753, dtype: float64

# %%
from datetime import datetime
df['company_age'] =  datetime.today().year-df.founded_year
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#    funding_total_usd     status country_code state_code         region  \
# 0          1750000.0   acquired          USA         NY  New York City
# 1          4000000.0  operating          USA         CA    Los Angeles
# 2            40000.0  operating          EST        NaN        Tallinn
# 3          1500000.0  operating          GBR        NaN         London
# 4            60000.0  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    category_list_count  company_age
# 0                    4         10.0
# 1                    1          NaN
# 2                    2         10.0
# 3                   10         11.0
# 4                    3          8.0

# %%
fig, ax = plt.subplots(1,2,figsize = (20,5))
ax[0].hist(df.grant)
ax[0].set_xlabel('Grant')
ax[0].set_ylabel('Count of Grant')
ax[0].set_title('Histogram of Grant')

ax[1].hist(np.log1p(df.grant), color = 'g')
ax[1].set_xlabel('Log of Grant')
ax[1].set_ylabel('Count of Grant')
ax[1].set_title('Histogram of Log transformed Grant')

plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize = (20,5))
ax[0].hist(df.debt_financing)
ax[0].set_xlabel('debt_financing')
ax[0].set_ylabel('Count of debt_financing')
ax[0].set_title("Histogram of debt_financing")

ax[1].hist(np.log1p(df.debt_financing), color = 'r')
ax[1].set_xlabel('debt_financing')
ax[1].set_ylabel('Count of debt_financing')
ax[1].set_title('Histogram of Log Transformed debt_financing')
plt.show()

# %%
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#    funding_total_usd     status country_code state_code         region  \
# 0          1750000.0   acquired          USA         NY  New York City
# 1          4000000.0  operating          USA         CA    Los Angeles
# 2            40000.0  operating          EST        NaN        Tallinn
# 3          1500000.0  operating          GBR        NaN         London
# 4            60000.0  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    category_list_count  company_age
# 0                    4         10.0
# 1                    1          NaN
# 2                    2         10.0
# 3                   10         11.0
# 4                    3          8.0

# %%
(df.status.value_counts()/df.shape[0])*100
# Out:
# operating    84.609005
# acquired      7.467940
# closed        5.265181
# Name: status, dtype: float64

# %%
df[df.country_code == 'USA']['state_code'].nunique()
# Out:
# 51

# %%
df['cmt_address'] = df.country_code + "-" + df.state_code + "-" + df.region + "-" + df.city

# %%
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#    funding_total_usd     status country_code state_code         region  \
# 0          1750000.0   acquired          USA         NY  New York City
# 1          4000000.0  operating          USA         CA    Los Angeles
# 2            40000.0  operating          EST        NaN        Tallinn
# 3          1500000.0  operating          GBR        NaN         London
# 4            60000.0  operating          USA         TX         Dallas
#
#           city  funding_rounds  founded_year  debt_financing  grant  \
# 0     New York               1        2012.0               0      0
# 1  Los Angeles               2           NaN               0      0
# 2      Tallinn               1        2012.0               0      0
# 3       London               1        2011.0               0      0
# 4   Fort Worth               2        2014.0               0      0
#
#    category_list_count  company_age                     cmt_address
# 0                    4         10.0   USA-NY-New York City-New York
# 1                    1          NaN  USA-CA-Los Angeles-Los Angeles
# 2                    2         10.0                             NaN
# 3                   10         11.0                             NaN
# 4                    3          8.0        USA-TX-Dallas-Fort Worth

# %%
df.filter(regex = '_').head()
# Out:
#                     homepage_url  \
# 0         http://www.waywire.com
# 1          http://enjoyandtv.com
# 2   http://www.rockyourpaper.org
# 3  http://www.InTouchNetwork.com
# 4                            NaN
#
#                                        category_list  funding_total_usd  \
# 0         |Entertainment|Politics|Social Media|News|          1750000.0
# 1                                            |Games|          4000000.0
# 2                             |Publishing|Education|            40000.0
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...          1500000.0
# 4                      |Tourism|Entertainment|Games|            60000.0
#
#   country_code state_code  funding_rounds  founded_year  debt_financing  \
# 0          USA         NY               1        2012.0               0
# 1          USA         CA               2           NaN               0
# 2          EST        NaN               1        2012.0               0
# 3          GBR        NaN               1        2011.0               0
# 4          USA         TX               2        2014.0               0
#
#    category_list_count  company_age                     cmt_address
# 0                    4         10.0   USA-NY-New York City-New York
# 1                    1          NaN  USA-CA-Los Angeles-Los Angeles
# 2                    2         10.0                             NaN
# 3                   10         11.0                             NaN
# 4                    3          8.0        USA-TX-Dallas-Fort Worth
